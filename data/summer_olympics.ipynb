# %% [markdown]
# ## Summer Cleaning

# %%
import pandas as pd
import numpy as np

# %%
# CSV location 
summer = 'SummerOlympicMedals.csv'

# %%
#Selecting columns, Renaming 
df_summer = pd.read_csv(summer, encoding="ISO-8859-1")
df_summer.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# To see the name of the columns
df_summer.count()
# Out:
# City            29216
# Edition         29216
# Sport           29216
# Discipline      29216
# Athlete         29216
# NOC             29216
# Gender          29216
# Event           29216
# Event_gender    29216
# Medal           29216
# dtype: int64

# %%
#Reading CSV, Selecting columns, Renaming 
df_summer = df_summer[["Edition", "Sport", "Discipline", "Athlete", "NOC", "Gender", "Event", "Medal"]]

# %%
df_summer=df_summer.rename(columns={"Edition":"year", "Sport":"sport", "Discipline":"discipline","Athlete": "athlete","NOC":"country_code","Gender":"gender", "Event":"event", "Medal":"medal"})
df_summer
# Out:
#        year      sport       discipline               athlete country_code  \
# 0      1896   Aquatics         Swimming         HAJOS, Alfred          HUN
# 1      1896   Aquatics         Swimming      HERSCHMANN, Otto          AUT
# 2      1896   Aquatics         Swimming     DRIVAS, Dimitrios          GRE
# 3      1896   Aquatics         Swimming    MALOKINIS, Ioannis          GRE
# 4      1896   Aquatics         Swimming    CHASAPIS, Spiridon          GRE
# ...     ...        ...              ...                   ...          ...
# 29211  2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko          GER
# 29212  2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas          LTU
# 29213  2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri          ARM
# 29214  2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain          CUB
# 29215  2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan          RUS
#
#       gender                       event   medal
# ...

# %%
df_summer.dtypes
# Out:
# year             int64
# sport           object
# discipline      object
# athlete         object
# country_code    object
# gender          object
# event           object
# medal           object
# dtype: object

# %%
df_summer= df_summer.loc[df_summer["year"] >= 1944,:]
df_summer
# Out:
#        year      sport       discipline                       athlete  \
# 7204   1948   Aquatics           Diving        CAPILLA PEREZ, Joaquin
# 7205   1948   Aquatics           Diving                   LEE, Samuel
# 7206   1948   Aquatics           Diving             HARLAN, Bruce Ira
# 7207   1948   Aquatics           Diving  CHRISTOFFERSEN-HANSON, Birte
# 7208   1948   Aquatics           Diving       DRAVES, Victoria Manalo
# ...     ...        ...              ...                           ...
# 29211  2008  Wrestling  Wrestling Gre-R                ENGLICH, Mirko
# 29212  2008  Wrestling  Wrestling Gre-R          MIZGAITIS, Mindaugas
# 29213  2008  Wrestling  Wrestling Gre-R               PATRIKEEV, Yuri
# 29214  2008  Wrestling  Wrestling Gre-R                 LOPEZ, Mijain
# 29215  2008  Wrestling  Wrestling Gre-R                BAROEV, Khasan
#
#       country_code gender         event   medal
# 7204           MEX    Men  10m platform  Bronze
# ...

# %%
df_summer["year"].unique()
# Out:
# array([1948, 1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988,
#        1992, 1996, 2000, 2004, 2008])

# %%
df_summer_sorted = df_summer.sort_values("year")

df_summer_sorted["medal_value"] = 0 
df_summer_sorted
# Out:
#        year       sport       discipline                 athlete country_code  \
# 7204   1948    Aquatics           Diving  CAPILLA PEREZ, Joaquin          MEX
# 7741   1948  Gymnastics      Artistic G.            LUCY, Robert          SUI
# 7742   1948  Gymnastics      Artistic G.         REUSCH, Michael          SUI
# 7743   1948  Gymnastics      Artistic G.          STALDER, Josef          SUI
# 7744   1948  Gymnastics      Artistic G.            STUDER, Emil          SUI
# ...     ...         ...              ...                     ...          ...
# 27847  2008  Basketball       Basketball         JIMENEZ, Carlos          ESP
# 27846  2008  Basketball       Basketball              GASOL, Pau          ESP
# 27845  2008  Basketball       Basketball             GASOL, Marc          ESP
# 27858  2008  Basketball       Basketball          KUZINA, Marina          RUS
# 29215  2008   Wrestling  Wrestling Gre-R          BAROEV, Khasan          RUS
#
# ...

# %%
#Adding value to "medal_value"
#rows = len(df_summer_sorted["medal"])

#for x in df_summer_sorted["medal"]:
 #   if x == "Gold":
  #      df_summer_sorted["medal_value"]=  3
   # else if x == "Silver":
    #    df_summer_sorted["medal_value"]=  2
   # else: 
    #    df_summer_sorted["medal_value"]=  1

# %%
#Remove duplicates 
#duplicates = df_summer_sorted.drop_duplicates(keep=False)
# duplicates.count()

# %% [markdown]
# ### Group by Year and Gender

# %%
summer_1948 = df_summer_sorted.loc[df_summer_sorted["year"] == 1948,:]
summer_1948.to_csv("summer_1948.csv",index=False, header=True)

# %%
summer_1952 = df_summer_sorted.loc[df_summer_sorted["year"] == 1952,:]
summer_1952.to_csv("summer_1952.csv",index=False, header=True)

# %%
summer_1956 = df_summer_sorted.loc[df_summer_sorted["year"] == 1956,:]
summer_1956.to_csv("summer_1956.csv",index=False, header=True)

# %%
summer_1960 = df_summer_sorted.loc[df_summer_sorted["year"] == 1960,:]
summer_1960.to_csv("summer_1960.csv",index=False, header=True)

# %%
summer_1964 = df_summer_sorted.loc[df_summer_sorted["year"] == 1964,:]
summer_1964.to_csv("summer_1964.csv",index=False, header=True)

# %%
summer_1968 = df_summer_sorted.loc[df_summer_sorted["year"] == 1968,:]
summer_1968.to_csv("summer_1968.csv",index=False, header=True)

# %%
summer_1972 = df_summer_sorted.loc[df_summer_sorted["year"] == 1972,:]
summer_1972.to_csv("summer_1972.csv",index=False, header=True)

# %%
summer_1976 = df_summer_sorted.loc[df_summer_sorted["year"] == 1976,:]
summer_1976.to_csv("summer_1976.csv",index=False, header=True)

# %%
summer_1980 = df_summer_sorted.loc[df_summer_sorted["year"] == 1980,:]
summer_1980.to_csv("summer_1980.csv",index=False, header=True)

# %%
summer_1984 = df_summer_sorted.loc[df_summer_sorted["year"] == 1984,:]
summer_1984.to_csv("summer_1984.csv",index=False, header=True)

# %%
summer_1988 = df_summer_sorted.loc[df_summer_sorted["year"] == 1988,:]
summer_1988.to_csv("summer_1988.csv",index=False, header=True)

# %%
summer_1992 = df_summer_sorted.loc[df_summer_sorted["year"] == 1992,:]
summer_1992.to_csv("summer_1992.csv",index=False, header=True)

# %%
summer_1996 = df_summer_sorted.loc[df_summer_sorted["year"] == 1996,:]
summer_1996.to_csv("summer_1996.csv",index=False, header=True)

# %%
summer_2000 = df_summer_sorted.loc[df_summer_sorted["year"] == 2000,:]
summer_2000.to_csv("summer_2000.csv",index=False, header=True)

# %%
summer_2004 = df_summer_sorted.loc[df_summer_sorted["year"] == 2004,:]
summer_2004.to_csv("summer_2004.csv",index=False, header=True)

# %%
summer_2008 = df_summer_sorted.loc[df_summer_sorted["year"] == 2008,:]
summer_2008.to_csv("summer_2008.csv",index=False, header=True)
